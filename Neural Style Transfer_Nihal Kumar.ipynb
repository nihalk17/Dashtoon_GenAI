# %% [markdown]
# # **Development of an Adaptable Deep Learning Model for Artistic Style Transfer**

# %%
import pandas as pd
import numpy as np
import os
from keras import backend as K
from keras.preprocessing.image import load_img, save_img, img_to_array
import matplotlib.pyplot as plt
from keras.applications import vgg19
from keras.models import Model
from scipy.optimize import fmin_l_bfgs_b

# %% [markdown]
# ## Loading the path for Base Content Image and the Style image respectively

# %%
 style_image_path = '/content/style1.png'
 base_image_path= '/content/content.jpg'

# %%
# dimensions of the generated picture.
width, height = load_img(base_image_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height)

# %% [markdown]
# ## This function is used to Preprocess the image with help of VGG19.

# %%
def preprocess_image(image_path):
    from keras.applications import vgg19
    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %%
plt.figure()
plt.title("Base Image",fontsize=20)
img1 = load_img(base_image_path)
plt.imshow(img1)

# %%
plt.figure()
plt.title("Style Image",fontsize=20)
img1 = load_img(style_image_path)
plt.imshow(img1)

# %%
# get tensor representations of our images

base_image = K.variable(preprocess_image(base_image_path))
style_reference_image = K.variable(preprocess_image(style_image_path))

# %%
K.image_data_format()
# Out:
# 'channels_last'

# %% [markdown]
# ### This will contain our generated image

# %%
# this will contain our generated image
if K.image_data_format() == 'channels_first':
    combination_image = K.placeholder((1,3,img_nrows, img_ncols))
else:
    combination_image = K.placeholder((1,img_nrows, img_ncols,3))

# %%
# combine the 3 images into a single Keras tensor
input_tensor = K.concatenate([base_image,
                              style_reference_image,
                              combination_image
                              ], axis=0)

# %% [markdown]
# ## Building the VGG19 model

# %%
# build the VGG19 network with our 3 images as input
# the model will be loaded with pre-trained ImageNet weights
from keras.applications.vgg19 import VGG19
vgg19_weights = '/content/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5'
model = VGG19(input_tensor=input_tensor,
              include_top = False,
              weights=vgg19_weights)

print(model)
# Out:
# <keras.src.engine.functional.Functional object at 0x7fe6f84defb0>

# %% [markdown]
# ##Excluding layers of VGG19 as our task here is not classification

# %%
# Content layer where will pull our feature maps
content_layers = ['block5_conv2']

# Style layer we are interested in
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1'
               ]

num_content_layers = len(content_layers)
num_style_layers = len(style_layers)

# %%
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
print(outputs_dict['block5_conv2'])
# Out:
# Tensor("block5_conv2_1/Relu:0", shape=(3, 25, 37, 512), dtype=float32)

# %% [markdown]
# ## The content Loss
# Given a chosen content layer **l**, the content loss is defined as the Mean Squared Error between the feature map **F** of our content image **C** and the feature map **P** of our generated image **Y**.
# ![Coontent Loss](https://cdn-images-1.medium.com/max/800/1*1YfGhmzBw7EK3e8CRpZbuA.png)

# %%
# an auxiliary loss function
# designed to maintain the "content" of the
# base image in the generated image
def get_content_loss(base_content, target):
    return K.sum(K.square(target - base_content))

# %% [markdown]
# ## The Style Loss
# To initiate the process, we calculate the Gram matrix for style layers, representing correlated features. A near-zero value implies non-simultaneous activation, while a large value signifies simultaneous activation in the style image. We aim to replicate this activation pattern in a mixed image.
#
# For a feature map matrix F, each entry in the Gram matrix G is given by
# ![Gram Matrix](https://cdn-images-1.medium.com/max/800/1*5xx9KmhVb59Mxe_buOwHBA.png)
#
# The style loss function is similar to content loss but involves Mean Squared Error for Gram matrices:

# %%
import tensorflow as tf
# the gram matrix of an image tensor (feature-wise outer product)
def gram_matrix(input_tensor):
    assert K.ndim(input_tensor)==3
    channels = int(input_tensor.shape[-1])
    a = tf.reshape(input_tensor, [-1, channels])
    n = tf.shape(a)[0]
    gram = tf.matmul(a, a, transpose_a=True)
    return gram#/tf.cast(n, tf.float32)

def get_style_loss(style, combination):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows*img_ncols
    return K.sum(K.square(S - C))#/(4.0 * (channels ** 2) * (size ** 2))

# %%
content_weight=0.025
style_weight=1.0
# combine these loss functions into a single scalar
loss = K.variable(0.0)
layer_features = outputs_dict['block5_conv2']
base_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
print('Layer Feature for Content Layers :: '+str(layer_features))
print('Base Image Feature :: '+str(base_image_features))
print('Combination Image Feature for Content Layers:: '+str(combination_features)+'\n')
loss = loss + content_weight * get_content_loss(base_image_features,
                                      combination_features)
# loss = loss + content_weight * total_variation_loss(combination_image)
# loss.assign_add(content_weight * get_content_loss(base_image_features,combination_features))

feature_layers = ['block1_conv1', 'block2_conv1',
                  'block3_conv1', 'block4_conv1',
                  'block5_conv1']
for layer_name in feature_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    print('Layer Feature for Style Layers :: '+str(layer_features))
    print('Style Image Feature :: '+str(style_reference_features))
    print('Combination Image Feature for Style Layers:: '+str(combination_features)+'\n')
    sl = get_style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(feature_layers)) * sl
# Out:
# Layer Feature for Content Layers :: Tensor("block5_conv2_1/Relu:0", shape=(3, 25, 37, 512), dtype=float32)
# Base Image Feature :: Tensor("strided_slice_22:0", shape=(25, 37, 512), dtype=float32)
# Combination Image Feature for Content Layers:: Tensor("strided_slice_23:0", shape=(25, 37, 512), dtype=float32)
#
# Layer Feature for Style Layers :: Tensor("block1_conv1_1/Relu:0", shape=(3, 400, 601, 64), dtype=float32)
# Style Image Feature :: Tensor("strided_slice_24:0", shape=(400, 601, 64), dtype=float32)
# Combination Image Feature for Style Layers:: Tensor("strided_slice_25:0", shape=(400, 601, 64), dtype=float32)
#
# Layer Feature for Style Layers :: Tensor("block2_conv1_1/Relu:0", shape=(3, 200, 300, 128), dtype=float32)
# Style Image Feature :: Tensor("strided_slice_28:0", shape=(200, 300, 128), dtype=float32)
# Combination Image Feature for Style Layers:: Tensor("strided_slice_29:0", shape=(200, 300, 128), dtype=float32)
#
# Layer Feature for Style Layers :: Tensor("block3_conv1_1/Relu:0", shape=(3, 100, 150, 256), dtype=float32)
# Style Image Feature :: Tensor("strided_slice_32:0", shape=(100, 150, 256), dtype=float32)
# Combination Image Feature for Style Layers:: Tensor("strided_slice_33:0", shape=(100, 150, 256), dtype=float32)
#
# Layer Feature for Style Layers :: Tensor("block4_conv1_1/Relu:0", shape=(3, 50, 75, 512), dtype=float32)
# Style Image Feature :: Tensor("strided_slice_36:0", shape=(50, 75, 512), dtype=float32)
# Combination Image Feature for Style Layers:: Tensor("strided_slice_37:0", shape=(50, 75, 512), dtype=float32)
#
# Layer Feature for Style Layers :: Tensor("block5_conv1_1/Relu:0", shape=(3, 25, 37, 512), dtype=float32)
# Style Image Feature :: Tensor("strided_slice_40:0", shape=(25, 37, 512), dtype=float32)
# Combination Image Feature for Style Layers:: Tensor("strided_slice_41:0", shape=(25, 37, 512), dtype=float32)

# %% [markdown]
# ## Features are extracted from each layer in style layers and content layers and their overall loss is calculated from it...

# %% [markdown]
# ### This deprocess_image function is used return the original format of the Final image  after transformation which could be easily read and displayed by Matplotlib.

# %%
loss
# Out:
# <KerasTensor: shape=() dtype=float32 (created by layer 'tf.__operators__.add_5')>

# %%
def deprocess_image(x):
    if K.image_data_format() == 'channels_first':
        x = x.reshape((3, img_nrows, img_ncols))
        x = x.transpose((1, 2, 0))
    else:
        x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %% [markdown]
# ### Calculation of gradient with respect to loss..

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %%
# get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)
grads
# Out:
# [<tf.Tensor 'gradients_5/concat_1_grad/Slice_2:0' shape=(1, 400, 601, 3) dtype=float32>]

# %%
outputs = [loss]
if isinstance(grads, (list,tuple)):
    outputs += grads
else:
    outputs.append(grads)
f_outputs = K.function([combination_image], outputs)
f_outputs

# %% [markdown]
# ##Using L-BFGS optimiser to optimise the loss and get the final image

# %%
# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x_opt = preprocess_image(base_image_path)

# %%
def eval_loss_and_grads(x):
    if K.image_data_format() == 'channels_first':
        x = x.reshape((1, 3, img_nrows, img_ncols))
    else:
        x = x.reshape((1, img_nrows, img_ncols, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# %%
class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

# %%
evaluator = Evaluator()

# %% [markdown]
# In this segment we run the code upto a given iteration. Although I would not recommend you to use **maxiter** parameter in **fmin_l_bfgs_b** to set the number of iterations.  Rarther use iteration in for loop to get better results

# %%
# %%time
iterations=500
# Store our best result
best_loss, best_img = float('inf'), None
for i in range(iterations):
    print('Start of iteration', i)
    x_opt, min_val, info= fmin_l_bfgs_b(evaluator.loss,
                                        x_opt.flatten(),
                                        fprime=evaluator.grads,
                                        maxfun=20,
                                        disp=True,
                                       )
    print('Current loss value:', min_val)
    if min_val < best_loss:
        # Update best loss and best image from total loss.
        best_loss = min_val
        best_img = x_opt.copy()
# Out:
# Start of iteration 0
# Current loss value: 8.083727e+20
# Start of iteration 1
# Current loss value: 3.3830945e+20
# Start of iteration 2
# Current loss value: 1.8794725e+20
# Start of iteration 3
# Current loss value: 1.2585184e+20
# Start of iteration 4
# Current loss value: 9.168366e+19
# Start of iteration 5
# Current loss value: 6.860644e+19
# Start of iteration 6
# Current loss value: 5.658234e+19
# Start of iteration 7
# Current loss value: 4.6926246e+19
# Start of iteration 8
# Current loss value: 3.9330573e+19
# Start of iteration 9
# Current loss value: 3.4285495e+19
# Start of iteration 10
# Current loss value: 3.0113585e+19
# Start of iteration 11
# Current loss value: 2.7054667e+19
# Start of iteration 12
# Current loss value: 2.4896965e+19
# Start of iteration 13
# Current loss value: 2.3020677e+19
# Start of iteration 14
# Current loss value: 2.1641505e+19
# Start of iteration 15
# Current loss value: 1.9943276e+19
# Start of iteration 16
# Current loss value: 1.874991e+19
# Start of iteration 17
# Current loss value: 1.73046e+19
# Start of iteration 18
# Current loss value: 1.5647239e+19
# Start of iteration 19
# Current loss value: 1.4649067e+19
# Start of iteration 20
# Current loss value: 1.386782e+19
# Start of iteration 21
# Current loss value: 1.3210833e+19
# Start of iteration 22
# Current loss value: 1.2641132e+19
# Start of iteration 23
# Current loss value: 1.2178416e+19
# Start of iteration 24
# Current loss value: 1.1741664e+19
# Start of iteration 25
# Current loss value: 1.1331144e+19
# Start of iteration 26
# Current loss value: 1.0905064e+19
# Start of iteration 27
# Current loss value: 1.049658e+19
# Start of iteration 28
# Current loss value: 1.0156535e+19
# Start of iteration 29
# Current loss value: 9.770003e+18
# Start of iteration 30
# Current loss value: 9.440223e+18
# Start of iteration 31
# Current loss value: 8.947689e+18
# Start of iteration 32
# Current loss value: 8.5155807e+18
# Start of iteration 33
# Current loss value: 8.287468e+18
# Start of iteration 34
# Current loss value: 8.102783e+18
# Start of iteration 35
# Current loss value: 7.931503e+18
# Start of iteration 36
# Current loss value: 7.7747116e+18
# Start of iteration 37
# Current loss value: 7.586518e+18
# Start of iteration 38
# Current loss value: 7.405715e+18
# Start of iteration 39
# Current loss value: 7.2585123e+18
# Start of iteration 40
# Current loss value: 7.116796e+18
# Start of iteration 41
# Current loss value: 6.9887576e+18
# Start of iteration 42
# Current loss value: 6.8716156e+18
# Start of iteration 43
# Current loss value: 6.7226197e+18
# Start of iteration 44
# Current loss value: 6.589112e+18
# Start of iteration 45
# Current loss value: 6.4441964e+18
# Start of iteration 46
# Current loss value: 6.300846e+18
# Start of iteration 47
# Current loss value: 6.127491e+18
# Start of iteration 48
# Current loss value: 5.9891355e+18
# Start of iteration 49
# Current loss value: 5.853814e+18
# Start of iteration 50
# Current loss value: 5.7414875e+18
# Start of iteration 51
# Current loss value: 5.6425705e+18
# Start of iteration 52
# Current loss value: 5.560835e+18
# Start of iteration 53
# Current loss value: 5.406837e+18
# Start of iteration 54
# Current loss value: 5.281579e+18
# Start of iteration 55
# Current loss value: 5.20612e+18
# Start of iteration 56
# Current loss value: 5.130489e+18
# Start of iteration 57
# Current loss value: 5.047672e+18
# Start of iteration 58
# Current loss value: 4.975752e+18
# Start of iteration 59
# Current loss value: 4.9106553e+18
# Start of iteration 60
# Current loss value: 4.8471574e+18
# Start of iteration 61
# Current loss value: 4.7700855e+18
# Start of iteration 62
# Current loss value: 4.70577e+18
# Start of iteration 63
# Current loss value: 4.634152e+18
# Start of iteration 64
# Current loss value: 4.5794236e+18
# Start of iteration 65
# Current loss value: 4.5078704e+18
# Start of iteration 66
# Current loss value: 4.4379931e+18
# Start of iteration 67
# Current loss value: 4.3806363e+18
# Start of iteration 68
# Current loss value: 4.3201843e+18
# Start of iteration 69
# Current loss value: 4.2407226e+18
# Start of iteration 70
# Current loss value: 4.1791893e+18
# Start of iteration 71
# Current loss value: 4.0967127e+18
# Start of iteration 72
# Current loss value: 4.0183758e+18
# Start of iteration 73
# Current loss value: 3.9605965e+18
# Start of iteration 74
# Current loss value: 3.9122322e+18
# Start of iteration 75
# Current loss value: 3.8606445e+18
# Start of iteration 76
# Current loss value: 3.8173084e+18
# Start of iteration 77
# Current loss value: 3.7787298e+18
# Start of iteration 78
# Current loss value: 3.736261e+18
# Start of iteration 79
# Current loss value: 3.6876468e+18
# Start of iteration 80
# Current loss value: 3.631838e+18
# Start of iteration 81
# Current loss value: 3.5908357e+18
# Start of iteration 82
# Current loss value: 3.5549855e+18
# Start of iteration 83
# Current loss value: 3.5231956e+18
# Start of iteration 84
# Current loss value: 3.4928763e+18
# Start of iteration 85
# Current loss value: 3.4640804e+18
# Start of iteration 86
# Current loss value: 3.4386154e+18
# Start of iteration 87
# Current loss value: 3.4029956e+18
# Start of iteration 88
# Current loss value: 3.372596e+18
# Start of iteration 89
# Current loss value: 3.329904e+18
# Start of iteration 90
# Current loss value: 3.294035e+18
# Start of iteration 91
# Current loss value: 3.25187e+18
# Start of iteration 92
# Current loss value: 3.2151916e+18
# Start of iteration 93
# Current loss value: 3.168749e+18
# Start of iteration 94
# Current loss value: 3.1292882e+18
# Start of iteration 95
# Current loss value: 3.1077457e+18
# Start of iteration 96
# Current loss value: 3.087923e+18
# Start of iteration 97
# Current loss value: 3.055736e+18
# Start of iteration 98
# Current loss value: 3.0296708e+18
# Start of iteration 99
# Current loss value: 3.013386e+18
# Start of iteration 100
# Current loss value: 2.9905303e+18
# Start of iteration 101
# Current loss value: 2.969869e+18
# Start of iteration 102
# Current loss value: 2.9542333e+18
# Start of iteration 103
# Current loss value: 2.936577e+18
# Start of iteration 104
# Current loss value: 2.9163488e+18
# Start of iteration 105
# Current loss value: 2.8990064e+18
# Start of iteration 106
# Current loss value: 2.8807235e+18
# Start of iteration 107
# Current loss value: 2.8588066e+18
# Start of iteration 108
# Current loss value: 2.83874e+18
# Start of iteration 109
# Current loss value: 2.8217121e+18
# Start of iteration 110
# Current loss value: 2.8038976e+18
# Start of iteration 111
# Current loss value: 2.7864044e+18
# Start of iteration 112
# Current loss value: 2.7688573e+18
# Start of iteration 113
# Current loss value: 2.7484803e+18
# Start of iteration 114
# Current loss value: 2.7314365e+18
# Start of iteration 115
# Current loss value: 2.7083797e+18
# Start of iteration 116
# Current loss value: 2.6892292e+18
# Start of iteration 117
# Current loss value: 2.6760302e+18
# Start of iteration 118
# Current loss value: 2.663369e+18
# Start of iteration 119
# Current loss value: 2.6461174e+18
# Start of iteration 120
# Current loss value: 2.6317974e+18
# Start of iteration 121
# Current loss value: 2.6111953e+18
# Start of iteration 122
# Current loss value: 2.594472e+18
# Start of iteration 123
# Current loss value: 2.578637e+18
# Start of iteration 124
# Current loss value: 2.5638453e+18
# Start of iteration 125
# Current loss value: 2.5491608e+18
# Start of iteration 126
# Current loss value: 2.5354012e+18
# Start of iteration 127
# Current loss value: 2.5210735e+18
# Start of iteration 128
# Current loss value: 2.5085622e+18
# Start of iteration 129
# Current loss value: 2.492058e+18
# Start of iteration 130
# Current loss value: 2.4767286e+18
# Start of iteration 131
# Current loss value: 2.465641e+18
# Start of iteration 132
# Current loss value: 2.4540465e+18
# Start of iteration 133
# Current loss value: 2.4434546e+18
# Start of iteration 134
# Current loss value: 2.4324493e+18
# Start of iteration 135
# Current loss value: 2.4221232e+18
# Start of iteration 136
# Current loss value: 2.404176e+18
# Start of iteration 137
# Current loss value: 2.388501e+18
# Start of iteration 138
# Current loss value: 2.377571e+18
# Start of iteration 139
# Current loss value: 2.3659563e+18
# Start of iteration 140
# Current loss value: 2.35517e+18
# Start of iteration 141
# Current loss value: 2.343783e+18
# Start of iteration 142
# Current loss value: 2.3308074e+18
# Start of iteration 143
# Current loss value: 2.318527e+18
# Start of iteration 144
# Current loss value: 2.308168e+18
# Start of iteration 145
# Current loss value: 2.297729e+18
# Start of iteration 146
# Current loss value: 2.2836132e+18
# Start of iteration 147
# Current loss value: 2.2691571e+18
# Start of iteration 148
# Current loss value: 2.2543999e+18
# Start of iteration 149
# Current loss value: 2.2366726e+18
# Start of iteration 150
# Current loss value: 2.2238513e+18
# Start of iteration 151
# Current loss value: 2.2103911e+18
# Start of iteration 152
# Current loss value: 2.195685e+18
# Start of iteration 153
# Current loss value: 2.1824202e+18
# Start of iteration 154
# Current loss value: 2.1743487e+18
# Start of iteration 155
# Current loss value: 2.1650899e+18
# Start of iteration 156
# Current loss value: 2.1563779e+18
# Start of iteration 157
# Current loss value: 2.1477398e+18
# Start of iteration 158
# Current loss value: 2.1398157e+18
# Start of iteration 159
# Current loss value: 2.1312664e+18
# Start of iteration 160
# Current loss value: 2.12359e+18
# Start of iteration 161
# Current loss value: 2.1160422e+18
# Start of iteration 162
# Current loss value: 2.1085949e+18
# Start of iteration 163
# Current loss value: 2.1018165e+18
# Start of iteration 164
# Current loss value: 2.0889318e+18
# Start of iteration 165
# Current loss value: 2.0780898e+18
# Start of iteration 166
# Current loss value: 2.0706138e+18
# Start of iteration 167
# Current loss value: 2.061784e+18
# Start of iteration 168
# Current loss value: 2.0548076e+18
# Start of iteration 169
# Current loss value: 2.0478606e+18
# Start of iteration 170
# Current loss value: 2.0380234e+18
# Start of iteration 171
# Current loss value: 2.0301757e+18
# Start of iteration 172
# Current loss value: 2.020767e+18
# Start of iteration 173
# Current loss value: 2.0123616e+18
# Start of iteration 174
# Current loss value: 2.0038472e+18
# Start of iteration 175
# Current loss value: 1.9959877e+18
# Start of iteration 176
# Current loss value: 1.9891246e+18
# Start of iteration 177
# Current loss value: 1.98219e+18
# Start of iteration 178
# Current loss value: 1.9758583e+18
# Start of iteration 179
# Current loss value: 1.9685982e+18
# Start of iteration 180
# Current loss value: 1.9607583e+18
# Start of iteration 181
# Current loss value: 1.9530314e+18
# Start of iteration 182
# Current loss value: 1.9442703e+18
# Start of iteration 183
# Current loss value: 1.9348597e+18
# Start of iteration 184
# Current loss value: 1.9274608e+18
# Start of iteration 185
# Current loss value: 1.9202102e+18
# Start of iteration 186
# Current loss value: 1.9125551e+18
# Start of iteration 187
# Current loss value: 1.9052423e+18
# Start of iteration 188
# Current loss value: 1.8942116e+18
# Start of iteration 189
# Current loss value: 1.8840426e+18
# Start of iteration 190
# Current loss value: 1.8773778e+18
# Start of iteration 191
# Current loss value: 1.8701148e+18
# Start of iteration 192
# Current loss value: 1.8581462e+18
# Start of iteration 193
# Current loss value: 1.8495942e+18
# Start of iteration 194
# Current loss value: 1.8417616e+18
# Start of iteration 195
# Current loss value: 1.8351334e+18
# Start of iteration 196
# Current loss value: 1.828808e+18
# Start of iteration 197
# Current loss value: 1.8223576e+18
# Start of iteration 198
# Current loss value: 1.8162027e+18
# Start of iteration 199
# Current loss value: 1.8093547e+18
# Start of iteration 200
# Current loss value: 1.802287e+18
# Start of iteration 201
# Current loss value: 1.7954498e+18
# Start of iteration 202
# Current loss value: 1.7880545e+18
# Start of iteration 203
# Current loss value: 1.7812655e+18
# Start of iteration 204
# Current loss value: 1.7693452e+18
# Start of iteration 205
# Current loss value: 1.7579472e+18
# Start of iteration 206
# Current loss value: 1.7513655e+18
# Start of iteration 207
# Current loss value: 1.7442746e+18
# Start of iteration 208
# Current loss value: 1.7386876e+18
# Start of iteration 209
# Current loss value: 1.7330491e+18
# Start of iteration 210
# Current loss value: 1.7266217e+18
# Start of iteration 211
# Current loss value: 1.72069e+18
# Start of iteration 212
# Current loss value: 1.7102424e+18
# Start of iteration 213
# Current loss value: 1.7010767e+18
# Start of iteration 214
# Current loss value: 1.6966785e+18
# Start of iteration 215
# Current loss value: 1.692176e+18
# Start of iteration 216
# Current loss value: 1.684597e+18
# Start of iteration 217
# Current loss value: 1.6772796e+18
# Start of iteration 218
# Current loss value: 1.6735295e+18
# Start of iteration 219
# Current loss value: 1.6691395e+18
# Start of iteration 220
# Current loss value: 1.6647328e+18
# Start of iteration 221
# Current loss value: 1.6605356e+18
# Start of iteration 222
# Current loss value: 1.6568134e+18
# Start of iteration 223
# Current loss value: 1.6521905e+18
# Start of iteration 224
# Current loss value: 1.648035e+18
# Start of iteration 225
# Current loss value: 1.6445739e+18
# Start of iteration 226
# Current loss value: 1.6411665e+18
# Start of iteration 227
# Current loss value: 1.6369344e+18
# Start of iteration 228
# Current loss value: 1.6295335e+18
# Start of iteration 229
# Current loss value: 1.6221415e+18
# Start of iteration 230
# Current loss value: 1.617291e+18
# Start of iteration 231
# Current loss value: 1.6116302e+18
# Start of iteration 232
# Current loss value: 1.6020581e+18
# Start of iteration 233
# Current loss value: 1.5947e+18
# Start of iteration 234
# Current loss value: 1.5908898e+18
# Start of iteration 235
# Current loss value: 1.5876589e+18
# Start of iteration 236
# Current loss value: 1.582702e+18
# Start of iteration 237
# Current loss value: 1.578533e+18
# Start of iteration 238
# Current loss value: 1.5750685e+18
# Start of iteration 239
# Current loss value: 1.5719912e+18
# Start of iteration 240
# Current loss value: 1.5659445e+18
# Start of iteration 241
# Current loss value: 1.5599061e+18
# Start of iteration 242
# Current loss value: 1.5556055e+18
# Start of iteration 243
# Current loss value: 1.5515626e+18
# Start of iteration 244
# Current loss value: 1.5463507e+18
# Start of iteration 245
# Current loss value: 1.5409532e+18
# Start of iteration 246
# Current loss value: 1.5359608e+18
# Start of iteration 247
# Current loss value: 1.5310107e+18
# Start of iteration 248
# Current loss value: 1.5247216e+18
# Start of iteration 249
# Current loss value: 1.5165656e+18
# Start of iteration 250
# Current loss value: 1.5120841e+18
# Start of iteration 251
# Current loss value: 1.5076216e+18
# Start of iteration 252
# Current loss value: 1.5043935e+18
# Start of iteration 253
# Current loss value: 1.5011936e+18
# Start of iteration 254
# Current loss value: 1.4977114e+18
# Start of iteration 255
# Current loss value: 1.4941075e+18
# Start of iteration 256
# Current loss value: 1.491172e+18
# Start of iteration 257
# Current loss value: 1.4872323e+18
# Start of iteration 258
# Current loss value: 1.4837953e+18
# Start of iteration 259
# Current loss value: 1.4809666e+18
# Start of iteration 260
# Current loss value: 1.4781363e+18
# Start of iteration 261
# Current loss value: 1.4752792e+18
# Start of iteration 262
# Current loss value: 1.472563e+18
# Start of iteration 263
# Current loss value: 1.4693563e+18
# Start of iteration 264
# Current loss value: 1.466363e+18
# Start of iteration 265
# Current loss value: 1.4632336e+18
# Start of iteration 266
# Current loss value: 1.4600097e+18
# Start of iteration 267
# Current loss value: 1.4565655e+18
# Start of iteration 268
# Current loss value: 1.4529117e+18
# Start of iteration 269
# Current loss value: 1.4491345e+18
# Start of iteration 270
# Current loss value: 1.4453618e+18
# Start of iteration 271
# Current loss value: 1.4423435e+18
# Start of iteration 272
# Current loss value: 1.4393643e+18
# Start of iteration 273
# Current loss value: 1.4366916e+18
# Start of iteration 274
# Current loss value: 1.4339693e+18
# Start of iteration 275
# Current loss value: 1.4311909e+18
# Start of iteration 276
# Current loss value: 1.4283599e+18
# Start of iteration 277
# Current loss value: 1.4236173e+18
# Start of iteration 278
# Current loss value: 1.4185025e+18
# Start of iteration 279
# Current loss value: 1.4148843e+18
# Start of iteration 280
# Current loss value: 1.4104064e+18
# Start of iteration 281
# Current loss value: 1.4047164e+18
# Start of iteration 282
# Current loss value: 1.400268e+18
# Start of iteration 283
# Current loss value: 1.3965469e+18
# Start of iteration 284
# Current loss value: 1.3927629e+18
# Start of iteration 285
# Current loss value: 1.3901198e+18
# Start of iteration 286
# Current loss value: 1.3871447e+18
# Start of iteration 287
# Current loss value: 1.3846308e+18
# Start of iteration 288
# Current loss value: 1.381946e+18
# Start of iteration 289
# Current loss value: 1.379963e+18
# Start of iteration 290
# Current loss value: 1.3759859e+18
# Start of iteration 291
# Current loss value: 1.3723601e+18
# Start of iteration 292
# Current loss value: 1.3697415e+18
# Start of iteration 293
# Current loss value: 1.3665833e+18
# Start of iteration 294
# Current loss value: 1.3610053e+18
# Start of iteration 295
# Current loss value: 1.353852e+18
# Start of iteration 296
# Current loss value: 1.3484959e+18
# Start of iteration 297
# Current loss value: 1.343449e+18
# Start of iteration 298
# Current loss value: 1.340239e+18
# Start of iteration 299
# Current loss value: 1.3376371e+18
# Start of iteration 300
# Current loss value: 1.3352067e+18
# Start of iteration 301
# Current loss value: 1.3328416e+18
# Start of iteration 302
# Current loss value: 1.3306295e+18
# Start of iteration 303
# Current loss value: 1.32846e+18
# Start of iteration 304
# Current loss value: 1.3264062e+18
# Start of iteration 305
# Current loss value: 1.3236508e+18
# Start of iteration 306
# Current loss value: 1.3203428e+18
# Start of iteration 307
# Current loss value: 1.3174763e+18
# Start of iteration 308
# Current loss value: 1.3138348e+18
# Start of iteration 309
# Current loss value: 1.3106599e+18
# Start of iteration 310
# Current loss value: 1.3078703e+18
# Start of iteration 311
# Current loss value: 1.3051558e+18
# Start of iteration 312
# Current loss value: 1.3025943e+18
# Start of iteration 313
# Current loss value: 1.2999295e+18
# Start of iteration 314
# Current loss value: 1.296471e+18
# Start of iteration 315
# Current loss value: 1.2934204e+18
# Start of iteration 316
# Current loss value: 1.2905555e+18
# Start of iteration 317
# Current loss value: 1.2876838e+18
# Start of iteration 318
# Current loss value: 1.2844708e+18
# Start of iteration 319
# Current loss value: 1.2816927e+18
# Start of iteration 320
# Current loss value: 1.2798673e+18
# Start of iteration 321
# Current loss value: 1.2777121e+18
# Start of iteration 322
# Current loss value: 1.2756783e+18
# Start of iteration 323
# Current loss value: 1.2729097e+18
# Start of iteration 324
# Current loss value: 1.2700492e+18
# Start of iteration 325
# Current loss value: 1.2673242e+18
# Start of iteration 326
# Current loss value: 1.265065e+18
# Start of iteration 327
# Current loss value: 1.2629407e+18
# Start of iteration 328
# Current loss value: 1.2610945e+18
# Start of iteration 329
# Current loss value: 1.2591791e+18
# Start of iteration 330
# Current loss value: 1.2571711e+18
# Start of iteration 331
# Current loss value: 1.2550824e+18
# Start of iteration 332
# Current loss value: 1.2531534e+18
# Start of iteration 333
# Current loss value: 1.2511318e+18
# Start of iteration 334
# Current loss value: 1.2492713e+18
# Start of iteration 335
# Current loss value: 1.2472133e+18
# Start of iteration 336
# Current loss value: 1.2453687e+18
# Start of iteration 337
# Current loss value: 1.2431058e+18
# Start of iteration 338
# Current loss value: 1.2408204e+18
# Start of iteration 339
# Current loss value: 1.23869e+18
# Start of iteration 340
# Current loss value: 1.2368313e+18
# Start of iteration 341
# Current loss value: 1.2348913e+18
# Start of iteration 342
# Current loss value: 1.233352e+18
# Start of iteration 343
# Current loss value: 1.2307939e+18
# Start of iteration 344
# Current loss value: 1.2281251e+18
# Start of iteration 345
# Current loss value: 1.2256519e+18
# Start of iteration 346
# Current loss value: 1.2232406e+18
# Start of iteration 347
# Current loss value: 1.221231e+18
# Start of iteration 348
# Current loss value: 1.2191665e+18
# Start of iteration 349
# Current loss value: 1.2168217e+18
# Start of iteration 350
# Current loss value: 1.2145957e+18
# Start of iteration 351
# Current loss value: 1.2126335e+18
# Start of iteration 352
# Current loss value: 1.2104518e+18
# Start of iteration 353
# Current loss value: 1.2085162e+18
# Start of iteration 354
# Current loss value: 1.2061181e+18
# Start of iteration 355
# Current loss value: 1.2035551e+18
# Start of iteration 356
# Current loss value: 1.2011344e+18
# Start of iteration 357
# Current loss value: 1.1989424e+18
# Start of iteration 358
# Current loss value: 1.1967263e+18
# Start of iteration 359
# Current loss value: 1.1947124e+18
# Start of iteration 360
# Current loss value: 1.19247e+18
# Start of iteration 361
# Current loss value: 1.1906203e+18
# Start of iteration 362
# Current loss value: 1.1881559e+18
# Start of iteration 363
# Current loss value: 1.1862785e+18
# Start of iteration 364
# Current loss value: 1.1846302e+18
# Start of iteration 365
# Current loss value: 1.1830762e+18
# Start of iteration 366
# Current loss value: 1.1813125e+18
# Start of iteration 367
# Current loss value: 1.1796939e+18
# Start of iteration 368
# Current loss value: 1.1756753e+18
# Start of iteration 369
# Current loss value: 1.1710311e+18
# Start of iteration 370
# Current loss value: 1.1678456e+18
# Start of iteration 371
# Current loss value: 1.1639004e+18
# Start of iteration 372
# Current loss value: 1.1619697e+18
# Start of iteration 373
# Current loss value: 1.1604119e+18
# Start of iteration 374
# Current loss value: 1.159106e+18
# Start of iteration 375
# Current loss value: 1.1578568e+18
# Start of iteration 376
# Current loss value: 1.1558799e+18
# Start of iteration 377
# Current loss value: 1.1541928e+18
# Start of iteration 378
# Current loss value: 1.1526493e+18
# Start of iteration 379
# Current loss value: 1.1512083e+18
# Start of iteration 380
# Current loss value: 1.1497746e+18
# Start of iteration 381
# Current loss value: 1.14845714e+18
# Start of iteration 382
# Current loss value: 1.1468784e+18
# Start of iteration 383
# Current loss value: 1.14527715e+18
# Start of iteration 384
# Current loss value: 1.1440056e+18
# Start of iteration 385
# Current loss value: 1.14242673e+18
# Start of iteration 386
# Current loss value: 1.1406862e+18
# Start of iteration 387
# Current loss value: 1.13881505e+18
# Start of iteration 388
# Current loss value: 1.1369552e+18
# Start of iteration 389
# Current loss value: 1.13512165e+18
# Start of iteration 390
# Current loss value: 1.1336117e+18
# Start of iteration 391
# Current loss value: 1.1313461e+18
# Start of iteration 392
# Current loss value: 1.12954554e+18
# Start of iteration 393
# Current loss value: 1.12813226e+18
# Start of iteration 394
# Current loss value: 1.1268164e+18
# Start of iteration 395
# Current loss value: 1.12555755e+18
# Start of iteration 396
# Current loss value: 1.1242054e+18
# Start of iteration 397
# Current loss value: 1.1228907e+18
# Start of iteration 398
# Current loss value: 1.12147114e+18
# Start of iteration 399
# Current loss value: 1.1201685e+18
# Start of iteration 400
# Current loss value: 1.1187151e+18
# Start of iteration 401
# Current loss value: 1.1171542e+18
# Start of iteration 402
# Current loss value: 1.1158244e+18
# Start of iteration 403
# Current loss value: 1.1146329e+18
# Start of iteration 404
# Current loss value: 1.1133561e+18
# Start of iteration 405
# Current loss value: 1.111699e+18
# Start of iteration 406
# Current loss value: 1.1100291e+18
# Start of iteration 407
# Current loss value: 1.108626e+18
# Start of iteration 408
# Current loss value: 1.1072094e+18
# Start of iteration 409
# Current loss value: 1.1058699e+18
# Start of iteration 410
# Current loss value: 1.10447716e+18
# Start of iteration 411
# Current loss value: 1.102403e+18
# Start of iteration 412
# Current loss value: 1.10052345e+18
# Start of iteration 413
# Current loss value: 1.0986041e+18
# Start of iteration 414
# Current loss value: 1.09674924e+18
# Start of iteration 415
# Current loss value: 1.0941404e+18
# Start of iteration 416
# Current loss value: 1.09169534e+18
# Start of iteration 417
# Current loss value: 1.0895598e+18
# Start of iteration 418
# Current loss value: 1.0874838e+18
# Start of iteration 419
# Current loss value: 1.08619826e+18
# Start of iteration 420
# Current loss value: 1.084825e+18
# Start of iteration 421
# Current loss value: 1.08365475e+18
# Start of iteration 422
# Current loss value: 1.08228634e+18
# Start of iteration 423
# Current loss value: 1.0807894e+18
# Start of iteration 424

# %% [markdown]
# ##**The Final Image**

# %%
# save current generated image
imgx = deprocess_image(best_img.copy())
plt.imshow(imgx)

# %%
plt.figure(figsize=(30,30))
plt.subplot(5,5,1)
plt.title("Base Image",fontsize=20)
img_base = load_img(style_image_path)
plt.imshow(img_base)

plt.subplot(5,5,1+1)
plt.title("Style Image",fontsize=20)
img_style = load_img(base_image_path)
plt.imshow(img_style)

plt.subplot(5,5,1+2)
plt.title("Final Image",fontsize=20)
plt.imshow(imgx)

# %% [markdown]
# This function **Run_Style_Transfer** is nothing but combination of all the above code that is discussed in the above cells part by part. It returns the final image after style transfer between two images.

# %% [markdown]
# # Conclusion
# * In our case the Final images formed are not totally perfect, because the Style image does not totally blend with the Base content image.
# * It could be improved through icreasing the number of iteration, or by trying out a different syle transfer algorithm which could preseve the edges of the base image, or by trying out with different optimizer to minimize gradient and loss.
